# %%
# %matplotlib notebook

import cv2           # The OpenCV library for opening and saving images
import numpy as np   # Array manipulations and other math stuff
from matplotlib import pyplot as plt # plotting graphs
import matplotlib
import matplotlib.image as mpimg

# %%
ls
# Out:
# Basic Image tutorial.ipynb
# Intsllation guide
# Python Programming Language Basics.ipynb
# airplane.png
# barbara.png
# cameraman.tif
# cameraman2.png
# cameraman_bright.png
# temp.py

# %%
img = cv2.imread('barbara.png', cv2.IMREAD_GRAYSCALE)

# view the image using opencv libraries
#cv2.imshow('original image', img)
#cv2.waitKey()
#cv2.destroyAllWindows()

# %%
# you can use various libraries to view images
img = mpimg.imread('cameraman.tif')
plt.figure()
imgplot = plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Lets make some operations and save the results

# change the data type of the image
img2 = img.astype('float64')

# Normalize the image
out = (img2 - np.min(img2))/(np.max(img2) - np.min(img2))
img_org = out.copy();

path = 'cameraman2.png'
plt.imsave(path, img, cmap='gray')

# increase the pixel intensity values in the image
out = out + 0.3
out[out > 1.0] = 1.0
out[out < 0.0] = 0.0

out_img = np.uint8(out*255)

plt.figure()
imgplot = plt.imshow(out_img, cmap='gray', vmin=0, vmax=255)
plt.show()

minVal = np.min(out_img)
maxVal = np.max(out_img)

# write the image to memory
path = 'cameraman_bright.png'
plt.imsave(path, out_img, cmap='gray', vmin=0,vmax=255)
#plt.savefig('cameraman_bright.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
